# %% [markdown]
# # Uso de un modelo LLM

# %% [markdown]
# ## LLM (también conocidos como Modelos)
# * Los LLM (Large Language Models, también llamados "Modelos") pueden interpretar y generar texto como los humanos. Son lo suficientemente versátiles como para escribir contenido, traducir idiomas, resumir y responder preguntas sin necesidad de entrenamiento especializado para cada tarea.

# %% [markdown]
# ## ¿Qué más pueden hacer los Modelos?
# Además de la generación de texto, muchos modelos soportan:
# * **Llamadas a herramientas** - invocar herramientas externas (como consultas a bases de datos o llamadas API) y usar los resultados en sus respuestas.
# * **Salida estructurada** - donde la respuesta del modelo está limitada a seguir un formato definido.
# * **Multimodalidad** - procesar y devolver datos distintos al texto, como
#     * imágenes,
#     * audio,
#     * y vídeo.
# * **Razonamiento** - los modelos realizan razonamiento en múltiples pasos para llegar a una conclusión.

# %% [markdown]
# ## El papel de los Modelos en las aplicaciones LLM y agentes IA
# Los modelos se pueden utilizar de dos formas:
# * Con agentes - Los modelos pueden especificarse dinámicamente al crear un agente.
# * De forma independiente - Los modelos se pueden llamar directamente (fuera del bucle del agente) para tareas como
#     * generación de texto,
#     * clasificación,
#     * o extracción
#     * sin necesidad de un framework de agentes.
#
# La misma interfaz de modelo funciona en ambos contextos, lo que te da la flexibilidad de empezar de forma sencilla y escalar a flujos de trabajo más complejos basados en agentes según sea necesario.
# * **Los modelos son el motor de razonamiento de las aplicaciones LLM y los agentes IA**. Impulsan el proceso de toma de decisiones del agente, determinando qué herramientas llamar, cómo interpretar los resultados y cuándo proporcionar una respuesta final.
# * **La calidad y capacidades del modelo que elijas impactan directamente en la fiabilidad y rendimiento base de tu agente**. Diferentes modelos destacan en diferentes tareas - algunos son mejores siguiendo instrucciones complejas, otros en razonamiento estructurado, y algunos soportan ventanas de contexto más grandes para manejar más información.

# %% [markdown]
# ## Recuerda, para usar un Modelo necesitarás cargar el archivo .env para asegurarte de que LangChain conoce la clave API del modelo que quieres usar
# * Cargarás el archivo .env al inicio de tu ejercicio así:

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## LangChain proporciona una forma estandarizada de usar Modelos
# * Cada modelo tiene una API diferente. En lugar de tener que aprender cada una de estas APIs, con LangChain tienes una forma estandarizada de acceder y usar la mayoría de modelos que existen.
# * Para una lista completa de modelos soportados en LangChain, consulta la página de [integraciones](https://docs.langchain.com/oss/python/integrations/providers/overview).

# %% [markdown]
# ## ¿Cuál es el mejor modelo LLM de OpenAI para usar en la clase de principiantes?
# Para una clase de **principiantes** de LangChain en enero de 2026, elegiremos **gpt-4o-mini** como predeterminado.
#
# ### ¿Por qué **gpt-4o-mini** es el mejor "valor predeterminado para enseñanza" ahora?
#
# * **Comportamiento predecible para agentes/llamadas a herramientas**: Los principiantes necesitan ejecuciones que "simplemente funcionen" para poder aprender *conceptos de LangChain* (mensajes, herramientas, memoria, salida estructurada) sin perseguir rarezas del modelo.
# * **Coste muy bajo** mientras sigue siendo fuerte en seguimiento de instrucciones y ayuda básica con código.
# * **Contexto abundante** para demostraciones de clase (contexto de 128k).
#
# ### Cuándo usar **gpt-5-mini**
#
# Usaremos **gpt-5-mini** cuando enseñemos:
#
# * **patrones agénticos** más complejos,
# * **selección/planificación de herramientas** más robusta,
# * cadenas más largas donde un poco más de "inteligencia" ayuda a los estudiantes a ver menos fallos extraños.
#
# Sigue siendo relativamente asequible comparado con los modelos insignia, pero notablemente más caro que 4o-mini.
#
# ### Por qué *no* usaríamos **gpt-5-nano** como predeterminado (como hace a menudo el equipo de LangChain en la documentación de LangChain)
#
# * Se comercializa como la variante GPT-5 **más rápida/más barata** y es genial para **resumen/clasificación**.
# * Pero se han reportado **problemas de integración reales con LangChain** donde `gpt-5-nano` puede devolver **contenido vacío** sin errores obvios—exactamente el tipo de confusión "¿por qué no se imprimió nada?" que descarrila una clase de principiantes.
#
# ### Nuestra recomendación práctica
#
# * **Recomendación predeterminada para todos los estudiantes:** **gpt-4o-mini**
# * **Sección "avanzada / bonus":** cambiar a **gpt-5-mini**

# %% [markdown]
# ## Conectar con el modelo LLM
# * Para este ejercicio, nos conectaremos con el modelo gpt-5-nano de OpenAI.

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-4o-mini",
    temperature=0.0
)

# %% [markdown]
# ## Qué hace este código
#
# ```python
# model = init_chat_model(
#     model="gpt-4o-mini",
#     temperature=0.0
# )
# ```
#
# Este código **crea un modelo de IA basado en chat** con el que tu aplicación de LangChain puede hablar.
#
# Piensa en ello como **conectar un cerebro de IA a tu programa** y decidir *cómo debe comportarse*.
#
# ---
#
# #### 1. `init_chat_model(...)`
#
# Esta es una **función auxiliar de LangChain** que:
#
# * Se conecta a un modelo de chat de OpenAI
# * Lo envuelve en una interfaz compatible con LangChain
# * Devuelve un objeto que puedes usar para enviar mensajes y recibir respuestas
#
# En términos simples:
#
# > "Configura un modelo de chat de IA para que mi código pueda hablar con él."
#
# ---
#
# #### 2. `model="gpt-4o-mini"`
#
# Esto elige **qué modelo de IA** quieres usar.
#
# * **gpt-4o-mini** es:
#
#   * Rápido ⚡
#   * Más barato 💸
#   * Aún muy capaz para razonamiento, resúmenes, clasificación y redacción
#
# Piensa en ello como:
#
# > "Usa una versión ligera pero inteligente de GPT-4."
#
# ---
#
# #### 3. `temperature=0.0`
#
# Esto controla **cuán creativo vs. predecible** es el modelo.
#
# * `temperature = 0.0` → muy factual, consistente, aburrido
# * `temperature = 1.0` → más creativo, variado, similar a humanos
# * `temperature > 1.0` → muy imaginativo, a veces caótico
#
# Así que aquí:
#
# > "Proporciona respuestas muy factuales y consistentes."
#
#
# ### Resumen en una frase
#
# > Este código configura un modelo de chat de nivel GPT-4 rápido con respuestas factuales para que tu aplicación LangChain pueda hablar con una IA.

# %%
response = model.invoke("¿Quién mató a JFK?")

print(response.content)
# Out:
# El asesinato del presidente John F. Kennedy ocurrió el 22 de noviembre de 1963 en Dallas, Texas. La Comisión Warren, que investigó el asesinato, concluyó que Lee Harvey Oswald fue el único responsable del crimen. Sin embargo, a lo largo de los años han surgido numerosas teorías de conspiración que sugieren la posible implicación de otros individuos o grupos. A pesar de estas teorías, la versión oficial sigue siendo que Oswald actuó solo.

# %% [markdown]
# ## .invoke vs. .stream para usar el Modelo en LangChain
# .invoke y .stream son las formas más frecuentes de usar un Modelo.
# * .invoke generará respuestas en pequeños fragmentos.
# * .stream generará respuestas en un flujo continuo, como lo que puedes ver en chatGPT.

# %%
response = model.invoke("¿Cuál es la mejor cafetería de San Francisco?")
print(response.content)
# Out:
# San Francisco tiene una gran variedad de cafeterías excelentes, y la "mejor" puede depender de tus preferencias personales. Algunas de las más populares y bien valoradas incluyen:
#
# 1. **Blue Bottle Coffee**: Conocida por su café de alta calidad y su enfoque en la frescura.
# 2. **Philz Coffee**: Famosa por su café preparado a medida y su ambiente acogedor.
# 3. **Ritual Coffee Roasters**: Ofrece granos de café de origen único y un ambiente moderno.
# 4. **Stumptown Coffee Roasters**: Reconocida por su café de especialidad y su compromiso con la sostenibilidad.
# 5. **The Mill**: Además de café, es famoso por su pan tostado artesanal.
#
# Te recomendaría visitar algunas de estas cafeterías y ver cuál se adapta mejor a tus gustos. ¡Cada una tiene su propio encanto!

# %%
for chunk in model.stream("¿Cuál es el mejor restaurante español de San Francisco?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |San| Francisco| tiene| una| vibr|ante| escena| gastron|ómica| y| varios| restaurantes| españoles| destacados|.| Uno| de| los| más| reconoc|idos| es| **|"|La| Mediterr|ánea|"|**,| que| ofrece| una| variedad| de| tapas| y| platos| tradicionales| españoles| en| un| ambiente| acog|edor|.| Otro| lugar| muy| apreci|ado| es| **|"|B|oc|ad|illos|"|**,| conocido| por| sus| delicios|os| boc|ad|illos| y| tapas|.
#
# |Sin| embargo|,| la| "|me|jor|"| opción| puede| depender| de| tus| preferencias| personales|,| como| el| tipo| de| comida| que| te| gusta|,| el| ambiente| que| buscas| y| tu| presupuesto|.| Te| recomendar|ía| revisar| las| rese|ñas| recientes| y| quizás| hacer| una| reserva|,| ya| que| algunos| de| estos| lugares| pueden| estar| bastante| concurr|idos|.||||

# %% [markdown]
# #### Qué hacen `.invoke()` vs `.stream()`:
#
# - **`.invoke()`**: Espera a la respuesta completa, luego te la da toda de una vez
# - **`.stream()`**: Te da la respuesta pieza por pieza mientras se está generando (como ver escribir a ChatGPT en tiempo real)
#
# #### Qué hace `end="|"` en el ejemplo de .stream():
#
# Normalmente, la función `print()` de Python añade un **salto de línea** al final, así que cada impresión aparece en una nueva línea:
# ```
# fragmento1
# fragmento2
# fragmento3
# ```
#
# Al usar `end="|"`, le estás diciendo a Python: "En lugar de un salto de línea, pon un carácter de tubería `|` al final." Esto hace que todo se imprima en la **misma línea**, separado por tuberías:
# ```
# fragmento1|fragmento2|fragmento3|
# ```
#
# #### ¿Por qué usarlo en este ejemplo?
#
# El `end="|"` es principalmente **con fines demostrativos** - te ayuda a **visualizar** que la respuesta está llegando en fragmentos separados en lugar de todo a la vez. Puedes ver literalmente dónde empieza y termina cada pieza.
#
# En una aplicación real, normalmente usarías `end=""` en su lugar (que significa "no añadas nada al final"), para que el texto fluya suavemente sin separadores - justo como ChatGPT se te muestra.
#
# La parte `flush=True` asegura que cada fragmento se muestre inmediatamente en lugar de esperar en un búfer.

# %% [markdown]
# ## Mira cómo funciona .stream en la mayoría de los casos

# %%
for chunk in model.stream("¿Cuál es el mejor Meetup para expatriados europeos en San Francisco?"):
    print(chunk.text, end="", flush=True)
# Out:
# San Francisco cuenta con varias comunidades y grupos de Meetup para expatriados europeos. Algunos de los más populares incluyen:
#
# 1. **European Expats in San Francisco**: Este grupo está diseñado específicamente para europeos que viven en la ciudad. Organizan eventos sociales, cenas y actividades culturales.
#
# 2. **International Friends San Francisco**: Aunque no es exclusivo para europeos, este grupo reúne a expatriados de diversas nacionalidades y organiza eventos que fomentan la interacción entre diferentes culturas.
#
# 3. **Young Professionals in San Francisco**: Este grupo atrae a muchos expatriados jóvenes, incluidos europeos, y ofrece oportunidades para hacer networking y socializar.
#
# 4. **Cultural Events and Activities**: Busca grupos que se centren en actividades culturales específicas, como cine, música o gastronomía europea.
#
# ...

# %% [markdown]
# ## Opciones avanzadas para streaming en LangChain 1.0
# En LangChain 1.0 tenemos algunas opciones avanzadas con streaming:
# * Transmitir progreso del agente — obtener actualizaciones de estado después de cada paso del agente.
#     * Esta opción es muy común en la mayoría de agentes IA de nivel de producción.
# * Transmitir tokens LLM — transmitir tokens del modelo de lenguaje a medida que se generan.
# * Transmitir actualizaciones personalizadas — emitir señales definidas por el usuario (ej., "Obtenidos 10/100 registros").
# * Transmitir múltiples modos — elegir entre actualizaciones (progreso del agente), mensajes (tokens LLM + metadatos) o personalizado (datos arbitrarios del usuario).
#
# Puedes ver cómo implementar estos enfoques avanzados en esta [página de documentación de LangChain](https://docs.langchain.com/oss/python/langchain/streaming).

# %% [markdown]
# ## Modelos alternativos

# %%
model2 = init_chat_model(model="claude-sonnet-4-5")

# %% [markdown]
# #### Algunos modelos como Gemini requieren importaciones personalizadas

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model3 = ChatGoogleGenerativeAI(model="gemini-3-pro-preview")

# %% [markdown]
# ## Cómo ejecutar este código desde Visual Studio Code
# * Abre el Terminal.
# * Asegúrate de estar en la carpeta del proyecto.
# * Asegúrate de tener el entorno poetry activado.
# * Introduce y ejecuta el siguiente comando:
#     * `python 001-using-llm-model.py`
